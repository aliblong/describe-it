# %%
import os
import sys
import re
import logging
from datetime import datetime, date, timedelta

level = 'INFO' #'ERROR'
logging.basicConfig(level=level)

import requests
from bs4 import BeautifulSoup

import numpy as np
import nltk as nl
import pandas as pd
import sklearn as sk

from sqlalchemy import create_engine, Column, Integer, BigInteger, String, DateTime
from sqlalchemy.orm import sessionmaker, aliased
from sqlalchemy_utils import database_exists, create_database
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.schema import FetchedValue
Base = declarative_base()

from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
# Database models
class Listing(Base):
    __tablename__ = 'listings'
    
    def __init__(self, id, **kwargs):
        self.id = id
        self.set_attributes(kwargs)

    def set_attributes(self,kwargs):
        for k, v in kwargs.items():
            setattr(self, k, v)
    
    id = Column(BigInteger, primary_key=True)
    title = Column(String)
    img = Column(String)
    url = Column(String)
    details = Column(String)
    description = Column(String)
    date_posted = Column(DateTime)
    location = Column(String)
    price = Column(String)
    date_scraped = Column(DateTime, FetchedValue())

class Subject(Base):
    __tablename__ = 'subjects'
    
    def __init__(self, name):
        self.name = name
    
    id = Column(BigInteger, primary_key=True)
    name = Column(String)
    date_last_scraped = Column(DateTime, FetchedValue())

class SubjectListing(Base):
    __tablename__ = 'subject_listings'
    
    def __init__(self, subject_id, listing_id):
        self.subject_id = subject_id
        self.listing_id = listing_id
    
    subject_id = Column(BigInteger, primary_key=True)
    listing_id = Column(BigInteger, primary_key=True)

# %%
# Derived from https://github.com/CRutkowski/Kijiji-Scraper
def parse_ad_summary(html):
    '''
    Parses several fields of a listing summary (except the description, which is truncated),
    then returns a dict of several these fields
    '''
    ad_info = {}
    
    try:
        ad_info['title'] = html.find('a', {'class': 'title'}).text.strip()
    except:
        logging.error('Unable to parse Title data.')

    try:
        ad_info['img'] = str(html.find('img'))
    except:
        logging.error('Unable to parse Image data')

    try:
        ad_info['url'] = 'http://www.kijiji.ca' + html.get('data-vip-url')
    except:
        logging.error('Unable to parse URL data.')

    try:
        ad_info['details'] = html.find('div', {'class': 'details'}).text.strip()
    except:
        logging.error('Unable to parse Details data.')

    raw_date = ''
    try:
        raw_date = html.find('span', {'class': 'date-posted'}).text.strip()
        # If the ad is less than 24h old, it's displayed as '< some amount of time'
        if raw_date[0] == '<':
            date = datetime.today().date()
        # Or "Yesterday"
        elif raw_date[0] == 'Y':
            date = datetime.today().date() - timedelta(days=1)
        else:
            date = datetime.strptime(raw_date, '%d/%m/%Y')
        ad_info['date_posted'] = date
    except:
        logging.error(f'Unable to parse Date data: \'{raw_date}\'')

    # The location field is affixed with the date for some reason
    try:
        location = html.find('div', {'class': 'location'}).text.strip()
        location = location.replace(raw_date, '')
        ad_info['location'] = location
    except:
        logging.error('Unable to parse Location data.')

    # In addition to normal prices, there can be 'Free' ($0), 'Please Contact' ($-1),
    # some other value ($-2), or empty ($-3)
    try:
        price = html.find('div', {'class': 'price'}).text.strip().split('\n')[0]
        if price[0] == '$':
            price = price[1:]
        elif price == 'Please Contact':
            price = '-1.00'
        elif price == 'Free':
            price = '0'
        else:
            price = '-2.00'
        ad_info['price'] = price
    except:
        logging.error('Unable to parse Price data.')
        ad_info['price'] = '-3.00'

    return ad_info 

def parse_ad_page(url):
    '''Parses the description from an ad page'''
    try:
        page = requests.get(url)
    except:
        logging.error('[Error] Unable to load ' + url)
        return None
    
    soup = BeautifulSoup(page.content, 'html.parser')
    
    try:
        return soup.find('div', {'itemprop': 'description'}).get_text()
    except:
        logging.error('Unable to parse ad description.')
        return None

def scrape(subject, existing_ad_ids = None, limit = None, url = None):
    '''
    Args are a search string for some subject, a list of existing ad IDs to skip,
    a limit to the number of results to return, and a url from which to start
    (in case, for example, a previous scrape was halted and is now being resumed).
    Returns (ads, already_scraped_ad_ids, all_ads_scraped); all_ads_scraped is whether
    or not an imposed limit was reached.
    '''
    # Initialize variables for loop
    ad_dict = {}
    # Shallow copy for now
    ad_ids_to_skip = existing_ad_ids if existing_ad_ids is not None else set()

    if url is None: url = \
        f'https://www.kijiji.ca/b-city-of-toronto/{subject}/k0l1700273?ll=43.650843,-79.377573&dc=true'

    ads_parsed = 0
    
    already_scraped_ad_ids = set()
    
    while url:

        try:
            page = requests.get(url)
        except:
            logging.error(f'[Error] Unable to load {url}')
            return

        soup = BeautifulSoup(page.content, 'html.parser')

        ads = soup.find_all('div', {'class': 'regular-ad'})
        
        # Skip third-party ads; these third parties are typically small retailers
        third_party_ads = soup.find_all('div', {'class': 'third-party'})
        third_party_ad_ids = set([int(ad['data-ad-id']) for ad in third_party_ads])
        
        # Parse ads until the limit is reached
        for ad in ads:
            title = ad.find('a', {'class': 'title'}).text.strip()
            ad_id = int(ad['data-ad-id'])
            
            if ad_id not in third_party_ad_ids:
                if ad_id not in ad_ids_to_skip:
                    logging.info(f'New ad found! Ad id: {ad_id}')
                    ad_info = parse_ad_summary(ad)
                    ad_url = ad_info['url']
                    description = parse_ad_page(ad_url)
                    if description is None: continue
                    ad_info['description'] = description 
                    ad_dict[ad_id] = ad_info
                    if limit is not None:
                        ads_parsed += 1
                        if ads_parsed >= limit: return ad_dict, already_scraped_ad_ids, url
                else:
                    logging.debug('Skip already-scraped ad')
                    already_scraped_ad_ids.add(ad_id)
            else:
                logging.debug('Skip third-party ad')
                
        url = soup.find('a', {'title' : 'Next'})
        if url:
            url_path = url['href']
            url = f'https://www.kijiji.ca{url_path}'

    return (ad_dict, already_scraped_ad_ids) if limit is None else (ad_dict, already_scraped_ad_ids, None)

# %%
def select_subject(subject, sess):
    return sess.query(Subject).filter_by(name=subject).first()

def update_date_scraped(subject, sess):
    subject_entry = select_subject(subject, sess)
    now = datetime.utcnow()
    subject_entry.date_last_scraped = now
    sess.merge(subject_entry)
    sess.commit()
    
def probe_subject(subject, sess):
    '''
    Returns (id, ads_to_skip), where id is the primary key for use in the 
    subject_listings table, and ads_to_skip is the list of ads already in the DB,
    or None if the subject has been scraped recently (< 1 day)
    '''
    subject_entry = select_subject(subject, sess)
    if not subject_entry:
        new_subject = Subject(subject)
        sess.add(new_subject)
        sess.commit()
        sess.refresh(new_subject)
        subject_id = new_subject.id
    else:
        subject_id = subject_entry.id
        now = datetime.utcnow()
        time_since_last_scrape = now - subject_entry.date_last_scraped
        freshly_scraped = time_since_last_scrape.days < 1
        if freshly_scraped:
            return subject_id, None
    
    listings = sess.query(Listing.id)
    # each returned element from a single-column select is a single-element tuple
    return subject_id, set([listing[0] for listing in listings])

def write_ads_to_db(subject_id, ads, sess):
    logging.info('Writing new ads to DB')
    listings = [Listing(id, **ad) for id, ad in ads.items()]
    for listing in listings:
        sess.merge(listing)
        sess.merge(SubjectListing(subject_id, listing.id))
        sess.commit()

def write_subject_listing_relations_for_already_scraped_ads_to_db(subject_id, already_scraped_ad_ids, sess):
    logging.info('Updating subject with ads already scraped')
    for already_scraped_ad_id in already_scraped_ad_ids:
        sess.merge(SubjectListing(subject_id, already_scraped_ad_id))
        sess.commit()

# %%
def connect_db():
    '''
    Returns a db session
    '''
    db_url = os.getenv('DB_URL')
    engine = create_engine(db_url)
    Session = sessionmaker(bind=engine)
    return Session()

# %%
def get_listings(subject):
    '''
    Returns a dataframe with all listings for a subject
    '''
    subject = subject.lower()
    sess = connect_db()
    subject_id, ads_to_skip = probe_subject(subject, sess)
    
    # Scrape unless it was done recently
    if ads_to_skip is not None:
        url = None
        all_ads_scraped = False
        # Every 50 ads, write to DB
        limit = 50
        while not all_ads_scraped:
            ads, already_scraped_ad_ids, url = scrape(subject, ads_to_skip, limit=limit, url=url)
            all_ads_scraped = True if url is None else False
            write_ads_to_db(subject_id, ads, sess)
            write_subject_listing_relations_for_already_scraped_ads_to_db(
                subject_id, already_scraped_ad_ids, sess)
            for ad_id in ads:
                ads_to_skip.add(ad_id)
                
        update_date_scraped(subject, sess)
    
    # This could be done with the ORM
    query = f'''
    select listing_id, title, description from (
        select * from subjects
            inner join subject_listings on subjects.id = subject_listings.subject_id where subjects.name = '{subject}'
    ) as this_subject_listings
        inner join listings on this_subject_listings.listing_id = listings.id;
    '''
    
    return pd.read_sql(query, sess.get_bind(), index_col='listing_id')

# %%
get_listings('bikes')
# Out:
#                                                         title  \
# listing_id
# 1386736775  Beautiful Panasonic Road Bike + Brand New U-lo...
# 1386736116    Norco Rio Vista Bike + New U-Lock for extra $20
# 1386735990          Vintage Raleigh Rocky II  bike for female
# 1386735687        Kona Hybrid Bike + New U-lock for extra $20
# 1386735255  Norco Sabre Cruiser Bike, Brand new tires + Ne...
# 1386734872  Raleigh Grand Prix Road Bike + New U-Lock for ...
# 1386734412  Orion Sport Japanese Road Bike + Brand New U-l...
# 1386730916                                      The good bike
# 1386728937  Northern Trail All Terrain  21-Spd Commuter - ...
# 1386728294  Vintage 1984 RALEIGH Royale road bike - like n...
# 1386727988        Petite AllPro 10-Spd road bike - 24" wheels
# 1386727510  Vintage Panasonic DX-2000 road bike 12-Spd - M...
# 1386661470                               Vintage 3-Speed Bike
# 1386725975                                        Trail Gator
# 1386724247                                         Trail Bike
# 1386723940  Vintage ladies 10 speed road bike - suits 5’3”...
# 1386723591  ~ Vintage Raleigh 12 speed road bike- 23” fram...
# 1386723318  ~ Vintage ladies 10 speed road bike - suits 5’...
# 1386723130  Bianchi Piaggio 12 speed road bike -- 21” fram...
# 1386721224                    Classic Cruiser Bike (Like New)
# 1386723940  Vintage ladies 10 speed road bike - suits 5’3”...
# 1386723591  Vintage Raleigh 12 speed road bike- 23” frame ...
# 1386723318  Vintage ladies 10 speed road bike - suits 5’4”...
# 1386723130  Bianchi Piaggio 12 speed road bike - 21” frame...
# 1386721224  Very Comfortable Urban Bike. It’s super cycle ...
# 1386719063  Very good condition bike\nReady to drive\nBrak...
# 1386718445  27'' vintage bike CCM 10 SPEED FRAME 33'' FOR ...
# 1386717885  26'' RALEIGH bike with 21 speed light weight, ...
# 1386717852  Womens hybrid bike, Nakamura, aluminum frame 1...
# 1386717566  Girls bike Louis Garneau, wheels 20'', very go...
# 1386717281  27'' racing bike CCM with 10 speed frame 35'' ...
# 1355515640  Bike racks for Rent - Thule & Saris Trunk/Rear...
# 1386716768  27'' ELECTRIC SCHWINN bike with 7 speed in new...
# 1386714705  Selling my ebike, very good condition with onl...
# 1373676078  Bikes WANTED. My passion is Canadian-made bike...
# ...                                                       ...
# 1384143645                Used women’s bike, very comfy seat.
# 1384141874  Great condition. Tires r 20 inch. Gear shifter...
# 1384135740  Selling my set of Planet Bike Speedez Road Fen...
# 1384130651  GT Agressor 21 inch bike rarely used, just dus...
# 1357499687  Great condition! Strada LX, 14 speed, shimano ...
# 1384125201  GT Ruckus 7 2.0 Downhill mountain bike for sal...
# 1384123792  Raleigh Medium Size Hybrid bike,Has 24 Speeds ...
# 1371317219  Price Is Negotiable\nWithout Training Wheels\n...
# 1384113051  Condition: Good and very Clean from SFPF home....
# 1384110568  Schwinn bike trainer for indoor use .\nEveryth...
# 1384108985                                        asking 200$
# 1370258983  "Mountain Tour" Oversized tubing frame bike, g...
# 1384071345                                         Girls bike
# 1384103363  Great condition deconstructed Minelli soloist ...
# 1384073766           Great way for kids to learn how to bike!
# 1384088228  16" (40.6 cm) high-tensile steel frame\n700C w...
# 1384085413  Very good condition vintage Bianchi road bike,...
# 1384083722  Lightly used, Specialized Sirrus Sport bike fo...
# 1384077405  IF THE AD IS UP IT IS STILL AVAILABLE.\nAlpine...
# 1384063154  Good condition 10 speed roadster, perfect for ...
# 1151933635  Trek Alpha Series 2300\nShimano Ultegra compon...
# 1384058130  Great bike for commuting/getting around the ci...
# 1384056005                   Holds 2 bikes hanging from trunk
# 1384054534  Have huffy tunder lady’s mountain bike with di...
# 1358338336  Bicycle Horn & Rear View MirrorDon't have have...
# 1384053185  Almost new, purchased a few months ago, used o...
# 1384053134  Mint Condition - 14.5” frame - 16 speed - Shim...
# 1384052791  I am moving on from my Raleigh fixed/fixie roa...
# 1384050149  700c hybrid bike\ngreat condition\npick up don...
# 1384047905  Vehicle Bike Rack in Excellent Condition; easy...
#
# [1473 rows x 2 columns]

# %% [markdown]
# Initialize spacy with the largest English CNN
#
# https://spacy.io/models/en#en_core_web_lg

# %%
import spacy
nlp_full = spacy.load('en_core_web_lg')
#nlp_tokenizer = spacy.load('en_core_web_lg', disable=['tagger'])

# %%
# Add personal possessive pronouns to stop-words collection
for ppp in ['my', 'your', 'their', 'his', 'her', 'our']:
    nlp_full.vocab[ppp].is_stop = True

# %%
import hunspell
hobj = hunspell.HunSpell('../dict/en_CA.dic', '../dict/en_CA.aff')

# %% [markdown]
# ## Get descriptions for a subject

# %%
my_subject = 'plasma tvs'
df = get_listings(my_subject)
# Kijiji uids look like unix timestamps, and afaict there's no way do stop
# pandas interpreting them as such while using orient='index'
#df.index = df.index.astype(np.int64) // 10**9
original_descs = [row['description'] for _, row in df.iterrows()]
#df
# Out:
# INFO:root:New ad found! Ad id: 1385265260
# ERROR:root:Unable to parse ad description.
# INFO:root:New ad found! Ad id: 1385199744
# INFO:root:New ad found! Ad id: 1385127111
# INFO:root:New ad found! Ad id: 1335300831
# ERROR:root:Unable to parse Price data.
# INFO:root:New ad found! Ad id: 1372011372
# INFO:root:New ad found! Ad id: 1372011612
# INFO:root:New ad found! Ad id: 1384902296
# INFO:root:New ad found! Ad id: 1384897841
# INFO:root:New ad found! Ad id: 1384836546
# ERROR:root:Unable to parse ad description.
# INFO:root:New ad found! Ad id: 1384816996
# INFO:root:New ad found! Ad id: 1384782660
# INFO:root:New ad found! Ad id: 1384664022
# INFO:root:New ad found! Ad id: 1384540387
# INFO:root:New ad found! Ad id: 1384523675
# INFO:root:New ad found! Ad id: 1126257783
# INFO:root:New ad found! Ad id: 1384380064
# INFO:root:New ad found! Ad id: 1384366411
# INFO:root:New ad found! Ad id: 1384310185
# INFO:root:New ad found! Ad id: 1384191627
# INFO:root:New ad found! Ad id: 1384194741
# INFO:root:New ad found! Ad id: 1384152772
# INFO:root:New ad found! Ad id: 1383981331
# INFO:root:New ad found! Ad id: 1383945671
# INFO:root:New ad found! Ad id: 1383862093
# ERROR:root:Unable to parse Price data.
# INFO:root:New ad found! Ad id: 1383850494
# INFO:root:New ad found! Ad id: 1383414122
# INFO:root:New ad found! Ad id: 1383393512
# INFO:root:New ad found! Ad id: 1383316354
# INFO:root:New ad found! Ad id: 1383057503
# INFO:root:New ad found! Ad id: 1382811453
# INFO:root:New ad found! Ad id: 1382600374
# INFO:root:New ad found! Ad id: 1382473186
# INFO:root:New ad found! Ad id: 1382316107
# INFO:root:New ad found! Ad id: 1382314672
# INFO:root:New ad found! Ad id: 1382110392
# INFO:root:New ad found! Ad id: 1381982672
# INFO:root:New ad found! Ad id: 1323996716
# INFO:root:New ad found! Ad id: 1381909838
# INFO:root:New ad found! Ad id: 1381731572
# INFO:root:New ad found! Ad id: 584217148
# ERROR:root:Unable to parse Price data.
# INFO:root:New ad found! Ad id: 1381685822
# INFO:root:New ad found! Ad id: 1367526751
# INFO:root:New ad found! Ad id: 1381027629
# INFO:root:New ad found! Ad id: 1380881569
# INFO:root:New ad found! Ad id: 1380704792
# INFO:root:New ad found! Ad id: 1380689475
# INFO:root:New ad found! Ad id: 1380680339
# INFO:root:New ad found! Ad id: 1184706533
# INFO:root:New ad found! Ad id: 1380316610
# INFO:root:New ad found! Ad id: 1380184145
# INFO:root:New ad found! Ad id: 1312526036
# INFO:root:New ad found! Ad id: 1380222874
# INFO:root:Writing new ads to DB
# INFO:root:Updating subject with ads already scraped
# INFO:root:New ad found! Ad id: 1380192837
# INFO:root:New ad found! Ad id: 1283316672
# INFO:root:New ad found! Ad id: 1379925682
# INFO:root:New ad found! Ad id: 1326549187
# INFO:root:New ad found! Ad id: 1366560800
# INFO:root:New ad found! Ad id: 1353136459
# INFO:root:New ad found! Ad id: 1379346340
# INFO:root:New ad found! Ad id: 1379300446
# INFO:root:New ad found! Ad id: 1379292242
# INFO:root:New ad found! Ad id: 1378992788
# INFO:root:New ad found! Ad id: 1378972588
# INFO:root:New ad found! Ad id: 1378379928
# ERROR:root:Unable to parse Price data.
# INFO:root:New ad found! Ad id: 1378379832
# ERROR:root:Unable to parse Price data.
# INFO:root:New ad found! Ad id: 1378199844
# INFO:root:New ad found! Ad id: 1377974906
# INFO:root:New ad found! Ad id: 1377918494
# INFO:root:New ad found! Ad id: 1377816491
# INFO:root:New ad found! Ad id: 1377518624
# INFO:root:New ad found! Ad id: 1282089630
# INFO:root:New ad found! Ad id: 1377145401
# INFO:root:New ad found! Ad id: 1377047678
# INFO:root:New ad found! Ad id: 1362546494
# INFO:root:New ad found! Ad id: 1364317622
# INFO:root:New ad found! Ad id: 1376943442
# INFO:root:New ad found! Ad id: 1363421473
# INFO:root:New ad found! Ad id: 1363421459
# INFO:root:New ad found! Ad id: 1376818396
# INFO:root:New ad found! Ad id: 1376781860
# INFO:root:New ad found! Ad id: 1222515812
# INFO:root:New ad found! Ad id: 1342778658
# INFO:root:New ad found! Ad id: 1323028967
# INFO:root:New ad found! Ad id: 1376488058
# INFO:root:New ad found! Ad id: 1376112972
# INFO:root:New ad found! Ad id: 1376028725
# INFO:root:New ad found! Ad id: 1335304197
# ERROR:root:Unable to parse Price data.
# INFO:root:New ad found! Ad id: 1375716984
# INFO:root:New ad found! Ad id: 589962401
# INFO:root:New ad found! Ad id: 1375184828
# INFO:root:New ad found! Ad id: 1374877101
# INFO:root:New ad found! Ad id: 1294865968
# INFO:root:New ad found! Ad id: 1374345721
# INFO:root:New ad found! Ad id: 1279411713
# INFO:root:New ad found! Ad id: 1373751692
# INFO:root:New ad found! Ad id: 1373703215
# INFO:root:New ad found! Ad id: 1373698697
# INFO:root:New ad found! Ad id: 1349973879
# ERROR:root:Unable to parse Price data.
# INFO:root:New ad found! Ad id: 1346971284
# ERROR:root:Unable to parse Price data.
# INFO:root:New ad found! Ad id: 1373368938
# INFO:root:New ad found! Ad id: 1149614105
# INFO:root:New ad found! Ad id: 1373437863
# INFO:root:Writing new ads to DB
# INFO:root:Updating subject with ads already scraped
# INFO:root:Writing new ads to DB
# INFO:root:Updating subject with ads already scraped

# %%
original_descs

# %% [markdown]
# ## Pre-processing
# * lowercasing all-caps and over-capped sentences
# * replacing measurements with tokens identifying their dimensionality and whether or not they carry a unit

# %%
def fix_capitalization(text):
    '''
    Lowercases sentences in a body of text that are either:
    * all-(or nearly-all-)caps
    Too many capitalized english words (very common in classifieds)
    '''
    sents = nl.tokenize.sent_tokenize(text)
    # First, figure out if a sentence is mostly caps, vs lowers and digits
    # Lowercasing mostly-caps sentences improves parsing, and using digits
    #   helps avoid targeting model names with this heuristic
    for i, sent in enumerate(sents):
        words = nl.tokenize.word_tokenize(sent)
        uppers = 0
        lowers_digits = 0
        capitalized_words = 0
        for word in words:
            for letter in word:
                if letter.isupper():
                    uppers += 1 
                elif letter.islower() or letter.isdigit():
                    lowers_digits += 1
            if word[0].isupper() and hobj.spell(word):
                capitalized_words += 1
                
        if uppers > lowers_digits * 3 or capitalized_words > 5:
            #print('SHAME')
            fixed_sent = sent.lower()
            sents[i] = fixed_sent
            
    return ' '.join(sents)

# %%
def replace_newlines_with_periods(descs):
    newline_with_optional_periods = re.compile('\.?\n')
    return [newline_with_optional_periods.sub('. ', desc) for desc in descs]

# %%
# I'm sure there's a way to generalize this regex,
# but I'm also sure nobody will be describing a four-dimensional feature
def normalize_measurements(descs):
    # start-of-line or whitespace
    SoL_or_WS = r'(^|\s)'
    # measurement
    m = r'(\d{1,9}|\d*\.\d+|\d+/\d+|\d+ \d+/\d+)'
    # dimensional separator
    DS = r'\s*[*xX×]\s*'
    unit = r'[-\s]*(\'|"|\w{1,2}\d?\.?\s+|in\.|inc?h?e?s?)\s*'
    unitless = r'(?:\s+|,)'
    # Unit and unitless regexes overlap, so they must be applied in that order
    dimension_regexes = []
    dimension_regexes.append(('32', re.compile(f'{SoL_or_WS}{m}{DS}{m}{DS}{m}{unit}'))) 
    dimension_regexes.append(('31', re.compile(f'{SoL_or_WS}{m}{DS}{m}{DS}{m}{unitless}')))
    dimension_regexes.append(('22', re.compile(f'{SoL_or_WS}{m}{DS}{m}{unit}')))
    dimension_regexes.append(('21', re.compile(f'{SoL_or_WS}{m}{DS}{m}{unitless}')))
    dimension_regexes.append(('12', re.compile(f'{SoL_or_WS}{m}{unit}')))
    dimension_regexes.append(('11', re.compile(f'{SoL_or_WS}{m}{unitless}')))

    #two_d_search = re.compile(r'(^|\s)(\d+)\s*[*x×]\s*(\d+)\s*(\w{1,2}\d?)')
    #two_d_replace = re.compile(r'^\1×\2\3')
    #three_d_search = re.compile(r'(^|\s)(\d+)\s*[*x×]\s*(\d+)\s*[*x×]\s*(\d+)\s*(\w{1,2}\d?)?')
    #two_d_replace = re.compile(r'\1×\2×\3\4')
    
    #measurements = {}
    #unnormalized_3d_measurements_in_descs = [three_d_search.findall(desc) for desc in descs]
    #unnormalized_2d_measurements_in_descs = [two_d_search.findall(desc) for desc in descs]
    #unnormalized_1d_measurements_in_descs = [one_d_search.findall(desc) for desc in descs]
   
    # Keyphrase with which to replace measurements
    # Will be affixed with dimensional info
    MK = '1029384756'
    
    original_descs = descs.copy()

    for dimension, regex in dimension_regexes:
        repl_template = f'{dimension}{MK}'
        for desc_i, desc in enumerate(descs):
            i = 0
            while True:
                subbed_desc = regex.sub(f' {repl_template}{i} ', desc, count = 1)
                if i > 20:
                    logging.error('too many measurements; probably a parsing error')
                    return
                if desc == subbed_desc: break
                desc = subbed_desc
            descs[desc_i] = desc

# %%
#yishu = pd.read_pickle('/home/aaron/Downloads/sephora_labeled_sent_new_new.p')

# %%
#yishus = [row['r_review'] for _, row in yishu.iterrows()]
#yishus

# %%
descs = original_descs.copy()
descs = replace_newlines_with_periods(descs)

normalize_measurements(descs)

descs = [fix_capitalization(desc) for desc in descs]

# %%
descs
# Out:
# ["TV WALL MOUNT EXPERTLED, LCD & PLASMAQuality service guaranteed! Getting things done right the first time!PRICES:. $75 - professional installation of customer provided basic mount. $85 - professional installation including basic mount ( up to 1210293847560 '). $105 - professional installation including premium tilt mount (up to 1210293847560 '). $150 - professional installation including premium full motion mount (up to 1210293847560 ')Extras:. $15 - basic wire concealment with sleek plastic wire cover. $25 - in-wall wire concealment. $25 - soundbar installation. $10 - 1210293847560 HDMI cables. $10 - 1210293847560 extension cordglass media shelves:. $45 - 1110293847560 tier shelf. $65 - 1110293847560 tier shelf. $85 - 1110293847560 tier shelf- Professional TV wall mounting. - Projectors and screen cinemas. - Sound and home theater systems. - Install Shelves and mirrors. - Hanging picture frames.CALL FOR FREE ESTIMATE/CONSULTATION416-856-0465TV. led. lcd. wall mount. installation",
#  "Trade or 1210293847560 dollars Cash. not negotiable... Simple42 Inch LG Plasma Television. NO issues... Comes with Desktop Stand. Comes with Wall mounts already installed on back. Comes with Wall mount Plate to mount on wall. Built in Hard drive for recording your shows. Power cord. Remote with multiple controlling functions. Photo's are of a DVD playing to show no bad pixels, and that it works. Awesome 1210293847560 TV or Kids Gaming TVIf you don't have a trade, you can use cash, 1210293847560 dollars. NOT negotiable. Will not Hold, unless an email money transfer for deposit is givenTrade for the either of the following. if you have a newer version, I may add cash,. Microsoft Surface Pro 1110293847560  or 4. With keyboard and cover and charger. In working condition with NO cracks in screen. NO RT'sSamsung Galaxy S3 Tablet. Doesn't need a keyboard, cover would be nice, but same as above. NO cracks, chips or glass separations.Trade, but as mentioned before, may be willing to add cash for the right machine....or 1110293847560 machines...etc... you get the ideaTelevision is located in Cambridge, 1110293847560 mins from 1210293847560 and Townline. Phone available by request.Additional pictures are items that can also be added for your S3 Tablet or Surface pro.",
#  'Panasonic 1210293847560 Plasma TV. Great condition. Not one thing wrong with it. Amazing quality for movies',
#  '35” x 27” - actual screen 28”. 28” Samsung HD Plasma TV with wall mount and stand. Works perfectly. Comes with swivel bracket to mount to wall and moves round the tv, the original tv stand and remote.',
#  'Excellent condition. Comes with remote and HDMI cable. Heavy, you will need 1110293847560 people to carry it. http://shop.panasonic.com/support-only/TH-42PD50U.html',
#  'Sony Bravia 1210293847560 TV. Great working condition & looks new. 1110293847560 HDMI inputs. Remote not included.',
#  'selling a mint plasma tv(50inch).....no low ballers!! !',
#  'Selling a used 1210293847560 Inch Plasma TV. This TV is still great for movies and videos games with true blacks and amazing brightness.$150 o.b.oCan drop off or be available for pick up in the GTA',
#  'Pioneer PDP 1210293847560 HD TV. 43” plasma TV needs receiver and remote.... you can buy receiver and remote on eBay for and $100 or can be used as a computer monitor using the DVI port, or used for parts.... $75 obo',
#  ' 1210293847560 plasma tv...prefect condition quick sale wanted 200.00',
#  'I\'m moving out of the country, but I love this TV and am sad to let it go. One of the most beautiful home TV screens I\'ve ever seen, makes watching anything feel like looking at art.59", Plasma, 1080P, with 1210293847560 capabilities (I never used them, but they\'re there!). It is not a Smart TV, but with a picture this good and an easy HDMI hookup to a computer or game console, it\'s a great deal for the price.The model is PN59550D. See specs and manufacturer description here:. https://www.abt.com/product/52717/samsung-59-series-5-black-flat-panel-plasma-hdtv-pn59d550.htmlthis quote from a digital trends review sums it up: "there’s a huge reason why we prefer plasma picture quality over practically any lcd hdtv we’ve experienced or reviewed — picture quality on this model is fan-tas-tic with a capital f. we’ve watched 1210293847560 “avatar” seemingly hundreds of times, most recently during many lcd test sessions. When we watched the first scene when the hospital ship sails through space on the [PN59550D] Samsung, there were colors we hadn’t seen since our initial viewing at the theater. Outer space had an inky blackness that LCD sets simply can’t match. Thanks to that depth, stars really shined, the red on the side of the spaceship popped—it was like seeing the movie for the first time. You really can’t ask for more than that. Picture quality is simply outstanding. "Will include a good Digital TV antenna as well, so you can watch TV on it as well. I\'m also selling, separately, an Xbox 1210293847560 which is a great way to watch DVDs on it (I hate having to mess with internet signal and love to rent and support our remaining video stores when the picture is this good). Let me know if you\'re interested in that.Would love to see this go to a good home and get many more years of love! Available for pickup near Dupont subway station for $450.',
#  "FREE ESTIMATE in Store. tv repair, service - we repair any brand names - models and makes- led tv, 3d, lcd tv, plasma tv, 4k, curved, oled, uhd, smart tv. - rca, samsung, lg, sony, toshiba, sharp, hitachi, panasonic,. - coby, insignia, hisense, dynex, hp, akai, haier, jvcfree estimatevideo, vcr, camerawe're specialized inlcd tv, led tv, plasma tv of any size. audio, video devicesin brampton : dixie and 407line problem, shadow image issue,. any other problems also,in store computer, laptop, dvr repair, rogers pvr, explorer 1210293847560 repair* since 1210293847560 * in store repair. * Free Estimates in store. *We Specialized in TV Repair. - lcd, plasma, dlp, projection. - pvr, dvr, hard drive recorder, rogers pvr problems,- 1210293847560 years of experience- computer repair - password removal, virus cleaning, data back up,. - Speed Up, Make more space in Hard Drive,. - dell, toshiba, acer, hp, any laptop, desktop / tower pc. - no power, broken screen,free estimate in storeemail if you need any service.",
#  'Hitachi 1210293847560 plasma TV. In good condition.',
#  "My kids and I were given a 1210293847560 plasma screen TV , but it's suffering from a ghosting effect that I can't fix. Since cash is tight, I am hoping to find someone willing to part with a decent flat screen (something over 1210293847560 , so it can be used in the living room).What I am offering: I have an electronic music keyboard that works well for anyone into playing music. Also, I can throw in $40 and/or some PS3 games, if necessary.Alternately, I know that all the 1210293847560 requires is for someone to disassemble the housing and tape down the video ribbons under the frame. If anyone is interested in it taking it on a trade, you'll likely have a working 1210293847560 without even having to buy parts.I don't have a vehicle, so would likely need you to swing by, unless you're in my area. Please do let me know.",
#  'See link below for details about this model. Tv works great, but I no longer have the neck to hold the tv on the stand (I had it on the wall). Would need a replacement piece or hang the tv on the wall- which is why the price is so low. https://www.lg.com/ca_en/tvs/lg-42PT350-plasma-tv',
#  '42” Samsung plasma tv. Great condition, hardly used, need to get rid of the asap',
#  ' 1210293847560 TV. Sd Card. Hdmi. S video and lots more inputs. Light line in the middle. Moving sale, needs to be gone asap. price is negotiable.',
#  'Samsung 1210293847560 DNIe SRS Tru Surround Xt Plasma TV with wood tv stand size. 1210293847560 wide by 1210293847560 long pick up only text msg or call must go asap. Price negotiable',
#  'Check out this link for specs:. Panasonic Viera TH-42PZ80 1210293847560 Plasma TV. Condition 1210293847560 Willing to negotiate price if you come today!',
#  "protech fl-535 37″ to 70″ full motion/articulating tv wall mount dual arm for lcd/led/plasma tv $74.99at tech vision electronics1261 kennedy road scarboroughwe carry 1210293847560 different wall mounts and ceiling mounts on the display come and check before you buy it. We do wholesale and retail. Any wholesale inquiries welcome. ***********************************. tech vision electronics. 1210293847560 kennedy road, unit d. scarborough, on, m1p 1210293847560 416-551-7334. www.techvisionelectronics.com. WE OPEN 1110293847560 DAYS A WEEK. MONDAY TO FRIDAY: 10:00AM TO 8:00 PM. SATURDAY: 10:00AM TO 6:00 PM. SUNDAY: 10:30AM TO 5:00 PM. ***********************************large full-motion tv wall mount 1210293847560 inch-70 inch tv wall mount $74.99model: protech 1210293847560 weight 1210293847560 lbs. Dimensions 3210293847560 Brand\tProtech. Colour\tBlack. Materials\tSteel. Surface Finish\tPowder Coating. Product Size 3210293847560 (24.2″ x 27″ x 16.9″) in open position. TV/Monitor Sizes 1210293847560 – 1210293847560 . Weight Capacity 1210293847560 / 143Lbs. vesa standards 1210293847560 200mm, 1210293847560 300mm, 1210293847560 200mm, 1210293847560 400mm, 2210293847560 installation\tdouble stud, solid wall. Profile 1210293847560 – 1210293847560 Motion Type\tFull Motion. Tilt Angle\t＋5° to -15°, Freely Tilting. Swivel Angle\t+60° to -60°. Level Adjustment\t+3° to -3°. warranty 1110293847560 year manufacturer's limited warrantyquick lock and release system holds tv in place with no tools requiredincludes:all tv mounting materials including m4, m5, m6 and m8 bolts. All wall mounting materials including screws and Fischer plugs. Easy assembly instructions***********************************. ***********************************. We Do Retail and Wholesale. Any inquiries for Wholesale are welcome. ***********************************. ***********************************. tech vision electronics. 1210293847560 kennedy road, unit d. scarborough, on, m1p 2l4(we are located right beside telecity & snow city)toll free 1-877-589-9869phone: 416-551-7334www.techvisionelectronics.comwe open 1110293847560 days a week. MONDAY TO FRIDAY: 10:00AM TO 8:00 PM. SATURDAY: 10:00AM TO 6:00 PM. sunday: 10:30am to 5:00 pmdon't forget to click poster's other ads for more great deals and similar items!we deal with hd tv antennas# channel master # antennas direct # winegard # focus antenna#tv antenna#8 bay antenna#4 bay antenna#antenna shop in toronto#antenna installation tools # channel master antenna # antenna direct # # best antenna # eaglestar pro # antra # power amplifiers cm 1210293847560 # cm7778 # hamza lte# channel master distribution amps # cm-3410 #cm-3412# cm-3414# cm-3418#cm-7777# cm-7778#cm-4221# cm-4228# channel master cm-9521 antenna direct db8 # antenna direct db4e # antenna direct db 1110293847560 # antennas direct db4e# db 4# db4e# db 8# db 8e# winegard # channel master cm-7777 titan2 uhf/vhf pre-amp # channel master cm-4228hd 8-bay # channel master dvr+ cm-7500 digital over-the-air hd tv tuner and recorder# focus high gain indoor hdtv (uhf) yagi antenna # antenna chimney mount# ota hdtv signal finder and meter# focus 4-bay # winegard flatwave# fl-5500# fl-5000 # cm-4221hd # hw150pvr # cm-9537 # channel master cm-9521a # fl-5500 # cm-4228hd# tdp2# db8# fl-6550# cm-4228hd combo # dual db4e combo # focus-8hd 1210293847560 # a/b switch# outdoor balun# 2-way splitter/combiner # in-line fm trap# fm band rejection filter # 1210293847560 # variable attenuator# am4262c # antennas direct 2-way uhf/vhf/fm distribution amp # cc-7870 # winegard cc-7870 combiner for 2-antennas # cda8 # pa18# lna-100# winegard boost indoor digital tv antenna amp# cpa19 # antenna mounting # antenna rotors# cable connectors and crimp tools # digital to analog converters # fm antennas # indoor antennas # outdoor antennas # rg6 cables # rg6 with grounding # signal meters and cable testers # adapters# audio & video cables# audio cables# brackets# bulk wire cables# cable extend ...
#  "TV WALL MOUNT EXPERTLED, LCD & PLASMAQuality service guaranteed! Getting things done right the first time!PRICES:. $75 - professional installation of customer provided basic mount. $85 - professional installation including basic mount ( up to 1210293847560 '). $105 - professional installation including premium tilt mount (up to 1210293847560 '). $150 - professional installation including premium full motion mount (up to 1210293847560 ')Extras:. $15 - basic wire concealment with sleek plastic wire cover. $25 - in-wall wire concealment. $25 - soundbar installation. $10 - 1210293847560 HDMI cables. $10 - 1210293847560 extension cordglass media shelves:. $45 - 1110293847560 tier shelf. $65 - 1110293847560 tier shelf. $85 - 1110293847560 tier shelf- Professional TV wall mounting. - Projectors and screen cinemas. - Sound and home theater systems. - Install Shelves and mirrors. - Hanging picture frames.CALL FOR FREE ESTIMATE/CONSULTATION416-856-0465TV. led. lcd. wall mount. installation",
#  "Tv stand, used to hold a 1210293847560 plasma. It's heavy and sturdy with thick glass shelves. Pickup at Islington and 1210293847560 only",
#  'north bayou mobile tv cart tv stand with wheels for 1210293847560 - 1210293847560 inch lcd led oled plasma flat panel screens up to 200lbs. Only for pick up at yonge and eglington',
#  'Pick up onlyUsed for PS4 gaming, and no longer needed.',
#  "TV WALL MOUNT EXPERTLED, LCD & PLASMAQuality service guaranteed! Getting things done right the first time!PRICES:. $75 - professional installation of customer provided basic mount. $85 - professional installation including basic mount ( up to 1210293847560 '). $105 - professional installation including premium tilt mount (up to 1210293847560 '). $145 - professional installation including premium full motion mount (up to 1210293847560 ')Extras:. $15 - basic wire concealment with sleek plastic wire cover. $25 - in-wall wire concealment. $25 - soundbar installation. $10 - 1210293847560 HDMI cables. $10 - 1210293847560 extension cordglass media shelves:. $45 - 1110293847560 tier shelf. $65 - 1110293847560 tier shelf. $85 - 1110293847560 tier shelf- Professional TV wall mounting. - Projectors and screen cinemas. - Sound and home theater systems. - Install Shelves and mirrors. - Hanging picture frames.CALL FOR FREE ESTIMATE/CONSULTATION416-856-0465TV. led. lcd. wall mount. installation",
#  " 1210293847560 lg plasma tv model number lg 42pc3dva-ud and 1210293847560 samsung plasma hp-t4264 both tv's they don't turn on if ad is still up, then item is still available",
#  " 1210293847560 lg plasma tv model number lg 42pc3dva-ud and 1210293847560 samsung plasma hp-t4264 both tv's they don't turn on if ad is still up, then item is still available",
#  'Stereo , Amplifier ( tube ) and any vintage electronics./ LED/LCD / Plasma TV , Projector. Best service and Affordable Service Charge. Available repair same day. 1210293847560 days parts and labour warranty. On business since 1210293847560 Call us anytime !! 416-558-3228 or www.repairtvtoronto.com. 1210293847560 Waterton Crescent Richmond hill',
#  'samsung 42-inch widescreen enhanced-definition plasma tv + panasonic 1110293847560 speaker surround sound systemtv model #: sp-p4231condition: excellent with power cord, remote, and panasonic 1110293847560 speaker surround sound systemfeatures:. - 1210293847560 widescreen high-definition plasma TV with DVI input; 3210293847560 (W x H x D) with speakers, without stand. - Accepts 1210293847560 and 1210293847560 signals and scales them for 1210293847560 viewing. - Extraordinary 1110293847560 000:1 contrast ratio, high 1110293847560 1110293847560 cd/m2 brightness. - NTSC dual-tuner, split-screen PIP lets you watch 1210293847560 puts simultaneously. - Includes Panasonic 1110293847560 speaker surround sound system including subwooferAll items come from a pet-free and smoke-free home.Text or email for any questions. Pickup around Yonge St. and Steeles Ave.',
#  'Plasma is considered the best technology for the cinematic experience. Great TV that worked flawlessly until this week. TV works but display is dim. If you can fix this problem, you will have a beautiful TV. Samsung model PN58A550S1F. Just $75. Scarborough. 416-605-6012',
#  "Great shape. Front and rear connections. 1210293847560 diagonal screen. This is a beautiful plazma tv. Moving cross country and I don't want to ship it. $500 obo. Details. Screen Size. 1210293847560 . Type. Consumer. Panel. Contrast Ratio. 10000:1. Model. Brand. Panasonic. Series. Viera. Details. Cabinet Color. Silver & Black. Panel. Native Resolution. 2210293847560 Aspect Ratio. 16:9. Panel. 1210293847560 Generation Plasma Panel. Display Colors. Maximum of 1210293847560 Billion. Pixel Pitch. 2210293847560 Connectivity. Input Video Compatibility. Tuner: NTSC , ATSC/QAM. HDTV: 480p/720p/1080i. HDTV Capability. HDTV Tuner Inside. Connectors. sd card slot(jpeg photo viewer). HDMI-HDCP Interface. Analog Audio Input (for HDMI). Composite Video Input. S-Video Input. Audio Input (for Video). component video input [y, pb(cb), pr(cr)]. Audio Input (for Component Video). Composite Video Output. Audio Output. Digital Audio Out. hdmi. Yes. Power. Power Supply. AC 1210293847560 V, 1210293847560 Power Consumption. 1210293847560 Convenience. Built-in Speakers. 1110293847560 (20W, 1110293847560 ohms, 1210293847560 - 17kHz, 10% THD). Features. Features. Shades of Gradation: 1110293847560 072. aspect control: 4:3, zoom, full, just, h-fill (tv/av). Progressive Scan. Video Noise Reduction. Digital Comb Filter: Motion Adaptive 3D-Y/C. Color Purity Optimizer (3D Color Management). Sub-Pixel Controller. Motion Pattern Noise Reduction. EZ Sync HDAVI Control, via HDMI interface. Video Picture Memory. On-Screen Display Languages: English/Spanish/French. V-Chip Program Lockout. Built-In Closed Caption Decoder. Timers - Sleep/On/Off: Sleep (Off only). Video Input Labeling. Dimensions & Weight. Dimensions (H x W x D). with pedestal stand: 1210293847560 x 1210293847560 x 1210293847560 . with out pedestal stand: 1210293847560 ' x 1210293847560 ' x 1210293847560 '. Weight. with pedestal stand: 1110293847560 lbs. with out pedestal stand: 1110293847560 lbs. Environmental. Temperature Range. 32°F - 104°F. Humidity Range. 20% - 80% (Non condensation)",
#  'Cash your broken LCD/PLASMA TV. I will pick up your broken TV, pay cash on site up to $50 . Price base on your TV, Please let me know. Make? Model? Size? Condition?. Thank you for your timekeywords: tv plasma led lcd samsung vizio pioneer sony bravia aquos sharp panasonic 1210293847560 1210293847560 1210293847560 1210293847560 1210293847560 1210293847560 1210293847560 wall mount stand television big screen flat screen',
#  'i will buy your broken, not working, needs repair led, lcd and plasma tv,s. Please email with TV info and TV problemkeywords: tv plasma led lcd samsung vizio pioneer sony bravia aquos sharp panasonic 1210293847560 1210293847560 1210293847560 1210293847560 1210293847560 1210293847560 1210293847560 wall mount stand television big screen flat screen',
#  "-Quality work at affordable rates. -Seamless wall mounting of LED/LCD/Plasma screen TV's of all makes and sizes. -TV wall mount professional Installations of any type of mounting brackets. -Sound bar installation. -I can provide TV wall mounts or install yours. -Tilting BRACKETS, FULL Motion BRACKETS!!. -I can also mount your mirrors, picture frames, shelves, curtains, blinds, etc. -Same day service. -I accept Cash, Email transfer, PayPal, Credit Card. For a free consultation and quote call or text Brian Romani: 647-904-3737",
#  'Free. 1110293847560 Sony floor standing speaker stands. 1110293847560 hitachi 1210293847560 motorized plasma tv STAND. No TV, just stand. rotates entire screen. No cable included.Pickup close to Eglinton West Subway Station.',
#  'Panasonic Viera - 1210293847560 plasma TV. Model TH42PZ85U. http://shop.panasonic.com/support-only/TH-42PZ85U.html. The TV is in good condition and never had any problems. It is coming with original remote in LIKE NEW condition(universal remote was used). i will also give away like new android tv box q-box with remote to make this a smart tv. https://forum.xda-developers.com/android-stick--console-computers/amlogic/q-box-review-amlogic-s905-t3384018',
#  'tv wall mount & hdmi cable sale 416-986-5786. location: sana, 1-1589 the queensway, etobicoke, on m8z 1210293847560 hours: mon-fri 1210293847560 - 7pm, sat 1210293847560 - 7pm, sun 1210293847560 - 1210293847560 1210293847560 - 1210293847560 led / plasma tv mount support mural (rotating) $17.99. 1210293847560 - 1210293847560 LED / PLASMA TV MOUNT w/Tilt $12.99. 1210293847560 - 1210293847560 LED / PLASMA TV MOUNT w/Tilt $23.99. 1210293847560 - 1210293847560 LED / PLASMA TV MOUNT w/Tilt $15.99. 1210293847560 Cat 1210293847560 Network / Data Cable $65.99. HDMI Cables:. 1210293847560 $2.69; 1210293847560 $3.99; 1210293847560 $7.75. and others...',
#  'Can hear sound but no image. Need to fix backlight',
#  ' 1210293847560 plasma TV kept in a spoke free condo. Works great and comes with the TV stand as well. Alternatively you can also purchase the wall mount for an extra $50.Specs as per the LG link below:. https://www.lg.com/ca_en/tvs/lg-50PV450-plasma-tv',
#  "TV WALL MOUNT EXPERTLED, LCD & PLASMAQuality service guaranteed! Getting things done right the first time!PRICES:. $75 - professional installation of customer provided basic mount. $85 - professional installation including basic mount ( up to 1210293847560 '). $105 - professional installation including premium tilt mount (up to 1210293847560 '). $150 - professional installation including premium full motion mount (up to 1210293847560 ')Extras:. $15 - basic wire concealment with sleek plastic wire cover. $25 - in-wall wire concealment. $25 - soundbar installation. $10 - 1210293847560 HDMI cables. $10 - 1210293847560 extension cordglass media shelves:. $45 - 1110293847560 tier shelf. $65 - 1110293847560 tier shelf. $85 - 1110293847560 tier shelf- Professional TV wall mounting. - Projectors and screen cinemas. - Sound and home theater systems. - Install Shelves and mirrors. - Hanging picture frames.CALL FOR FREE ESTIMATE/CONSULTATION416-856-0465TV. led. lcd. wall mount. installation",
#  'Diagonal clas (metric) 1210293847560 2hdmi port. Plasma HD Tv. Sd memo card input',
#  ' 1210293847560 Panasonic High Definition Plasma TV. Model:TH-50PX6U. Vivid Bright Color. good condition comes with original remote controlbonus: will give a way a fully functional ups apc; this will provide 1210293847560 minutes of power something like that after power outage and provide protection for other electronic devices as well.$160 price is firm.',
#  'I am selling a 43” Samsung flat screen TV (series F4500) that works like new. I am including a wall mount that I used with it, and the original stand as well. Resolution 2210293847560 HDMI ports: 2. USB port: 1. Weight: 30lbs. Remote Control included. Pick up only at Adelaide & John. Text for a quick reply 1210293847560 1210293847560 982I',
#  'duramex (tm) lcd led plasma tv flat panel swivel tilt full motion wall mount, screen bracket, articulating, cantilever dual arms 1210293847560 1210293847560 1210293847560 1210293847560 1210293847560 1210293847560 (free shipping)',
#  "Rare to find, Brand new,. monoprice above fireplace height adjustable swivel tv pull down mantel wall mount for lcd led plasma screen displays 1210293847560 to 1210293847560 | maximum weight 70lbs | vesa 2210293847560 to 2210293847560 tvs look great above your fireplace and mantel, but they're difficult to watch when mounted so high. With the Monoprice Firelace Mount, the TV can conveniently be pulled down from the wall to eye-level to prevent neck pain. The TV can also be tilted and swiveled conveniently, for the most comfortable TV viewing experience. Capable of mounting any television with a VESA mounting pattern of 2210293847560 2110293847560  this mount is ideal for TVs ranging from 1210293847560 1210293847560 , weighing up to 1110293847560 pounds.",
#  "protech mounts tl 1210293847560 tilting tv wall mount 1210293847560 inch tv- holds up to 1210293847560 (75 kg) lcd/led/plasma/curve tvs/ tilting tv bracket/heavy duty tv wal mount bracket for $59.99we carry 1210293847560 different wall mounts and ceiling mounts on the display come and check before you buy it. We do wholesale and retail. Any wholesale inquiries welcome. ***********************************. ***********************************tech vision electronics. 1210293847560 kennedy road, unit d. scarborough, on, m1p 1210293847560 (we are located right beside telecity & snow city). TOLL FREE 1-877-589-9869. PHONE: 416-551-7334. www.TechVisionElectronics.com. WE OPEN 1110293847560 DAYS A WEEK. MONDAY TO FRIDAY: 10:00AM TO 8:00 PM. SATURDAY: 10:00AM TO 6:00 PM. SUNDAY: 10:30AM TO 5:00 PM***********************************. ***********************************model:\ttl 1210293847560 lprice: $59.99main tv\tsizes 1210293847560 1210293847560 weight capacity 1210293847560 / 1210293847560 vesa standard(s) 2210293847560 / 2210293847560 / 2210293847560 / 2210293847560 / 2210293847560 / 2210293847560 / 2210293847560 / 2210293847560 / 2210293847560 / 2210293847560 features\tmotion. Type Tilting Tilt Angle± 15° Up-Down. distance from wall to tv 1210293847560 / 1210293847560 mounting wall studs required 1210293847560 . Stud Spacing\tYes 1210293847560 Stud. Spacing Yes. wall plate (length x width) 2210293847560 / 2210293847560 height of tv bracket rails 1210293847560 / 1110293847560 inch. Physical Colour\tBlack. Materials Solid Steel. shipping dimensions (length x width x height) 3210293847560 / 3210293847560 weight 1210293847560 / 1210293847560 includes wall mounting hardware yes. Assembly Instructions Yes. Warranty 1110293847560 Year Limited Covers materials and workmanship against manufacturing defects during the course of normal usage***********************************. ***********************************. We Do Retail and Wholesale. Any inquiries for wholesale are welcome. ***********************************. ***********************************tech vision electronics. 1210293847560 kennedy road, unit d. scarborough, on, m1p 1210293847560 (we are located right beside telecity & snow city). TOLL FREE 1-877-589-9869. PHONE: 416-551-7334. www.TechVisionElectronics.com. WE OPEN 1110293847560 DAYS A WEEK. MONDAY TO FRIDAY: 10:00AM TO 8:00 PM. SATURDAY: 10:00AM TO 6:00 PM. SUNDAY: 10:30AM TO 5:00 PM. we deal with hd tv antennas# channel master # antennas direct # winegard # focus antenna#tv antenna#8 bay antenna#4 bay antenna#antenna shop in toronto#antenna installation tools # channel master antenna # antenna direct # # best antenna # eaglestar pro # antra # power amplifiers cm 1210293847560 # cm7778 # hamza lte# channel master distribution amps # cm-3410 #cm-3412# cm-3414# cm-3418#cm-7777# cm-7778#cm-4221# cm-4228# channel master cm-9521 antenna direct db8 # antenna direct db4e # antenna direct db 1110293847560 # antennas direct db4e# db 4# db4e# db 8# db 8e# winegard # channel master cm-7777 titan2 uhf/vhf pre-amp # channel master cm-4228hd 8-bay # channel master dvr+ cm-7500 digital over-the-air hd tv tuner and recorder# focus high gain indoor hdtv (uhf) yagi antenna # antenna chimney mount# ota hdtv signal finder and meter# focus 4-bay # winegard flatwave# fl-5500# fl-5000 # cm-4221hd # hw150pvr # cm-9537 # channel master cm-9521a # fl-5500 # cm-4228hd# tdp2# db8# fl-6550# cm-4228hd combo # dual db4e combo # focus-8hd 1210293847560 # a/b switch# outdoor balun# 2-way splitter/combiner # in-line fm trap# fm band rejection filter # 1210293847560 # variable attenuator# am4262c # antennas direct 2-way uhf/vhf/fm distribution amp # cc-7870 # winegard cc-7870 combiner for 2-antennas # cda8 # pa18# lna-100# winegard boost indoor digital tv antenna amp# cpa19 # antenna mounting # antenna rotors# cable connectors and crimp tools # digital to analog converters # fm antennas # indoor antennas # outdoor antennas # rg6 cables # rg6 with grounding  ...
#  'Selling TV 1210293847560 . Good condition. Reason of sale: I’m moving out so I can not carry. Contact me soon if you are interested. Thanks',
#  'Selling a 1110293847560 tiered glass TV stand. Was used to hold up our 1210293847560 plasma (tv was bought in 1210293847560 it is very heavy). Measurements are:. 1210293847560 length x 1210293847560 depth x 1210293847560 height. Asking $85. Pickup in Pickering.',
#  "TV WALL MOUNT EXPERTLED, LCD & PLASMAQuality service guaranteed! Getting things done right the first time!PRICES:. $75 - professional installation of customer provided basic mount. $85 - professional installation including basic mount ( up to 1210293847560 '). $105 - professional installation including premium tilt mount (up to 1210293847560 '). $150 - professional installation including premium full motion mount (up to 1210293847560 ')Extras:. $15 - basic wire concealment with sleek plastic wire cover. $25 - in-wall wire concealment. $25 - soundbar installation. $10 - 1210293847560 HDMI cables. $10 - 1210293847560 extension cordglass media shelves:. $45 - 1110293847560 tier shelf. $65 - 1110293847560 tier shelf. $85 - 1110293847560 tier shelf- Professional TV wall mounting. - Projectors and screen cinemas. - Sound and home theater systems. - Install Shelves and mirrors. - Hanging picture frames.CALL FOR FREE ESTIMATE/CONSULTATION416-856-0465TV. led. lcd. wall mount. installation",
#  'panasonic tcp50x5 plasma tv partsn0ae6jk00006 (b159-201) power supply unit. TXN/A1SFUUS (TNPH1001UB) A Board. TXNSN1RHUU (TNPA5593) SN Board for TC-P50X5/TC-P50XT50. TBL5ZX0337 Stand. TXNC11RHUU (TNPA5590) C1 Board. TXNC21RHUU (TNPA5591) C2 Board. TXN/K1SGUUS (TNPA5602AD) K BoardEXCHANGE SERVICE / REPAIRNote: We need the Old Parts, without old parts, the sales price of our parts will be more than advertised.1. Your board has never been repaired or never been replaced any parts or missing parts. 2. Burnt, cracked, liquid spill or damage from an attempted repair is not an acceptable condition for repairing. 3. If your board has been repaired or replaced parts, it may increase the extra bill up to $35. 4. Shipping and Pickup Must be done by customer. for shipping infomation please talk to sales, call in advance for pickup in store.products may not be exactly as pictured, price and availability subject to change without notice.',
#  'Panasonic TCP55ST30 Plasma TV PartsTXN/A1PAUUS A Board. TXNSD1PAUU (TNPA5341) SD Board. TXNSU1PAUU (TNPA5340) SU Board. TXNSC1PAUU (TNPA5351) SC Board. TXNSS1PAUU (TNPA5359) SS Board. TXN/P1PAUU (N0AE6KK00007) POWER BoardEXCHANGE SERVICE / REPAIRNote: We need the Old Parts, without old parts, the sales price of our parts will be more than advertised.1. Your board has never been repaired or never been replaced any parts or missing parts. 2. Burnt, cracked, liquid spill or damage from an attempted repair is not an acceptable condition for repairing. 3. If your board has been repaired or replaced parts, it may increase the extra bill up to $35. 4. Shipping and Pickup Must be done by customer. for shipping infomation please talk to sales, call in advance for pickup in store.products may not be exactly as pictured, price and availability subject to change without notice.',
#  'Panasonic plasma tv 1210293847560 1210293847560 dollars or best offer',
#  'Plasma TV in good condition works perfect. Tv + stand for 1210293847560 Just tv 1210293847560 Just stand 1210293847560 Thanks. If you are interested please text call or email me',
#  'Legend 42” TV in excellent condition,comes with working remote, picture and sound are great 1210293847560 best offer',
#  'Please check our other ads everything is for sale! Everything must go!. moving sale!!!!!! everything must go!!!!. Plasma TV for sale 1210293847560 comes with back bracket and wall mount. Comes with Remote. Please contact via cell 4168908023',
#  'Used once or twice, completely functional. Looking to get rid of stuff for moving purposes. Please only message if seriously interested and able to pick up.',
#  '$135 ONLY. +++ DELIVERY OPTION AVAILABLE for a few bucks depending on where you live. +++ Works GREAT and in Good Condition !! Nice Picture. This Samsung 1210293847560 1210293847560 plasma TV has 1110293847560 HDMI ports and a headphone jack. OEM remote control /converter included !! call or text 647-226-997.pick up in front of subway restaurant at lake shore and albert avenue (2378 lake shore boulevard west, etobicoke, m8v 1c3). DELIVERY OPTION AVAILABLE for a few bucks depending on where you live.Please note: If you see this ad, this item is still available. My ads are promptly taken down once the item is sold. For a quick response, please call or text 647-226-9997. Thanks for looking. Please see my other ads for more great items!',
#  'Model# CMP4211 U. VGA input/output only. Quite old but still work well. Stand not included.',
#  'board numbers: anp2090-a. model numbers: pdp-504pu. PART TYPE: Y-Driver. TV TYPE AND SIZE: Plasma, 1210293847560 . MFR PART NUMBER: Pioneer AWV2147',
#  'Selling a used Sharp Aquos LCD TV. Model LC-42D62U. NEEDS REPAIR - TV has a problem where black lines appear on the screen, see photos. Solution is to replace the main board. Selling AS-IS. Comes with remote and original instruction booklet.Pick up in Scarborough. Pharmacy and Steeles',
#  ' 1210293847560 plasma TV for sale. Includes DVI to HDMI converter.',
#  'Selling Samsung Tv 1210293847560 black color comes with the remote.',
#  'Like new 1210293847560 Panasonic Viera plasma tv. All cables and remotes included.',
#  'Selling a barely used 1210293847560 Plasma TV Panasonic Viera that comes with the stand. The TV is almost brand new as I rarely watch TV. I bought the set 1110293847560 years ago costing me around $1200 together. The model number: Tc-p50st30',
#  'Retails for 400$$$. Bargain. perfect TV bracket Portable for conferences, exhibitions, showcases, schools, etc ... Can support TVs from 1210293847560 to 1210293847560 . Can support a maximum weight of 1210293847560 / 1210293847560 Lbs. Compatible with VESA standard 2210293847560 up to 2210293847560 Height of the TV 1210293847560 to 1210293847560 from the ground (1150 mm to 1210293847560 mm). 1210293847560 multiple feasible height levels of 1210293847560 (50mm). Included a tablet 2210293847560 component (17.7 "x 1210293847560 ). The tablet height is adjusted at will. The TV can be installed in portrait or landscape. total weight of the support: (approx 1210293847560 / 1210293847560 lbs). BLACK resistant sprayed coating. Hardware store and manual included. Easy Installation',
#  'Hello, I’m moving. Wanna sell a tv 1210293847560 . Price: $220',
#  'Please contact me with any questions',
#  'tv wall mount installation, lcd ,led and plasma, please call: 1210293847560 1210293847560 wall mounting on concrete wall, drywall and above the fireplace, all wires professionally being concealed to eliminate all the hanging wires to perform the best look on your entertainment area, our clean and professional work brings us more clients from our previous customers! Guaranteed service satisfaction! Professional installation and Same Day service are available! We match other prices to keep you happy! Customer satisfaction is our number one priority! Former best buy and future shop installers, now run Independent company for more than a decade! www.homevisionpro.com. tel: 1210293847560 1210293847560 all kind of tv wall mounts and tv brackets are available( flat, tilt & full motion), hdmi cables, ,optical cables, shelves, ….',
#  'Have this 1210293847560 tv no longer works. The screen won’t turn on but there’s power to the tv. If it does turn on it will turn on and off. Asking $90',
#  'I have a LG 1210293847560 Plasma in Excellent working condition. Only used occasionally. We have replaced with a new tv. Model 60PK550 - Originally purchased for $2200',
#  ' 1210293847560 LG Plasma TV. 1210293847560 HD. Remote, TV Stand and Wall Mount included. Model 60PA6500',
#  ' 1210293847560 year old used Samsung 1210293847560 Plasma TV with minor issue (developing horizontal lines on screen) in good working condition on sale. Pickup is on buyer on a as is basis from my place.',
#  '32” LG XD TV brand new in a box',
#  'Tv only $40. Stand only $30. Both for $50',
#  'See link for details about this model. https://www.lg.com/ca_en/tvs/lg-42PT350-plasma-tv',
#  "I have a 1210293847560 plasma screen TV that is flickering. if you have an extra flat screen tv that works and you want to unload it, i can trade with you for a ps4 game (battlefront) and maybe a few other ps3 games (need for speed: the run, call of duty ghosts and heavenly sword). Please let me know. I'm looking for any flat screen that works and that I can watch some TV on with my kids.",
#  'Tv + stand for sale , Thornhill area Yonge/Steeles',
#  '50” plasma tv for sale. Still working in great condition.',
#  'This is not a smart tv',
#  'techcraft lcd/plasma stand black',
#  "I am selling my barely used TV because i am moving out the country. This TV works well. Is well kept in excellent condition. Its local pick up only. Price is for fast sale. If you know Viesa technology, it is the best Panasonic offers. Please don't waste your or my time with different low offers . (( if you see my ad it means it is still for sale )). Low ballers will not be replied. Thanks for looking.",
#  ' 1210293847560 screen (measured diagonally). glossy screen, black bezel and cabinet. tuner receives over-the-air HDTV broadcasts (antenna required). QAM cable TV tuner (subscription required to receive cable channels — contact your local service provider for details). displays 1210293847560 images when you wear Samsung\'s active 1210293847560 glasses (2 pairs of glasses are included). 2D-to-3D conversion adds 3D-like depth to non-3D video sources. 1210293847560 Subfield Motion for clear video motion. Internet-ready Smart TV — plays Netflix® video and more (subscription required for some services). supports up to 5.1-channel audio with streaming movie services like Netflix and Vudu™ (audio quality depends on your connection speed). built-in Wi-Fi® to link to a wireless network. built-in web browser. dual-core processor for improved web browsing and app multitasking. AllShare™ video and music streaming from a DLNA-compatible Windows® PC. MHL-compatible HDMI input for viewing photos/videos from a compatible smartphone on the TV\'s screen. 2-way screen mirroring via Wi-Fi — send content wirelessly from device-to-TV or TV-to-device with compatible Samsung smartphones and tablets. built-in stereo speakers (10 watts x 2). illuminated touchpad remote with built-in microphone for voice control. free downloadable Android app lets you use a compatible smartphone or tablet as a remote control. Anynet+ simplifies control of compatible Samsung components via the HDMI connection (HDMI-CEC). meets ENERGY STAR® requirements. Connections and Dimensions:. 1110293847560 A/V inputs, including:. 1110293847560 HDMI. 1110293847560 component video (selectable component/composite). RF input for antenna/cable signals. optical digital audio output. Ethernet port for a wired connection to a home network. 1110293847560 USB inputs for connecting a camera or thumb drive. detachable swivel stand (stand "footprint" is 32-1/4"W x 14-3/4"D). wall-mountable (bracket not included). 1210293847560 W x 32-5/8"H x 2-9/16"D (36-3/4"H x 14-3/4"D on stand). weight: 1110293847560 lbs. with stand; 1110293847560 lbs. without stand',
#  'Brand new complete in the box. Supports TV from 1210293847560 to 1210293847560 (94 cm to 1210293847560 cm). Max weight of 1210293847560 pounds. Complete with instruction manual',
#  "offers a fast, professional and friendly in-home lcd, led, plasma television repair service in toronto!. ------------------------------------------------------------------------------------------------------------------------------------->>>>>>>>a mission to make you happy<<<<<<<<>>>we beat competitor prices and help our valuable customers & save money!<<<television repair toronto - in home projection tv repairs, we realise that moving and transporting large, modern flat screen tvs can present significant problems. to address this issue, we offer a full in home repair service. All in home television repairs are carried out to the same high standards as in our own workshops and all in home repairs are covered by our comprehensive guarantee. we cover most addresses within the toronto area and can usually arrange our visit at a time that's convenient to you.we service: samsung, lg, sharp, panasonic, toshiba, rca, pioneer prima, etc... led tv ,. lcd tv. plasma tv>>>>>>http://www.ledtvrepair.ca......................... http://www.bramptontvrepair.ca>>>> brampton location address: 30-melanie dr unit 1110293847560 steeles & torbram>>>>>>contact.......(416)662-5414 >> ronny singh>>>>>>>toronto...........(416)740-4444>>>>>>>brampton........(905)793-3030*thanks for business!",
#  'Plasma TV with remote. No stand. It works however has display issue. You can use it for parts. $60 obo. Can drop for extra price',
#  'led/lcd / plasma tv , projector , stereo , amplifier ( tube ) and any vintage electronics.best service and affordable service charge. Available repair same day. 1210293847560 days parts and labour warranty. Free Estimates, Free Pickup & Delivery. on business since 1210293847560 we serve area : toronto, markham, scarborough, pickering, etobicoke, brampton, mississauga, vaughan, richmond hill, newmarket, concorde, and more.. Call us anytime !! 416-558-3228 or www.repairtvtoronto.com. 1210293847560 Waterton Crescent Richmond hill',
#  "'''''00'''''wall mounting any LCD, LED or Plasma call 1210293847560 1210293847560 just remember one name. install-ONTARIOwe are company trained professionals. We will install your TV or sound system according to your needswe carry all hardware to make your installation easy and joyful,. so you don't have to worry about anythingorSelect our Super Discounted all in one installation Package includeswall mounting your up to 1210293847560 TV. All wires vertical concealed inside the drywall. FREE TV wall mount. wall plates provided. extension cord provided. all other necessary hard ware provided. call for quoteCall 1210293847560 1210293847560 ;. ;. ;. ;'. 'toronto ajax pickring oshawa hilton hamilton hilton lcd wall mounting led wall mounting plasma wall mounting tv installation installation tv wall mounting flat screen tv installation tv installation tv wall mounting lcd tv wall mounting tv wall installation tv wall mount contractors wall mount contractors plasma tv wall mount installation lcd tv wall mount. 1210293847560 1210293847560 76598-0665653 1210293847560 4655",
#  ' 1210293847560 Samsung plasma tv. Very good condition. With remote',
#  'selling broken silver Lg 1210293847560 plasma tv for parts. contact if interested.',
#  'Used. Comes as is. Cables and TV remote included. TV stand can be included as well.',
#  'Pick up only. LG 42” plasma tv . Posted in buy and sell, electronics in City of Toronto. August 1110293847560  2018',
#  'Audiophile plasma tvFrom mature and non pet homeVery lightly used over the yearsNo flawsComes with original manual and remoteThanks',
#  "Was given this by a friend, I never use it. It's got HDMI and USB ports, remote control included. Pickup at Bloor and St.Helens, close to Lansdowne Station. 1210293847560 obo",
#  'TV Fujitsu Plasmavision 1210293847560',
#  "$525 each firm or $1,000 for both firm.I have 1210293847560 inch LG Plasma TV's 1210293847560 resolution for sale as we are downsizing from a house to a small Condo. Both of these have very little use as we are not home very often and we don't watch too much TV at all.Both TV's have a fantastic picture and comes with the remotes and TV stands. No issues with the picture quality at all whatsoever.Ad will be removed when sold, so please assume that they are still for sale if you see this ad. Serious inquiries only. Lowballers will be ignored.",
#  'Panasonic TH-42PA20 1210293847560 Plasma TV in excellent condition. Remote control is included. $60',
#  'TV Panasonic Rivera',
#  'Tv only, does not come with wall mount. Model number is in the second photo.Asking $400, located in Scarborough',
# ...
#  'insignia, dynex, toshiba, viziokdl-32s5100lcd, led tv, plasma tv, 3d, 4k, curved, oled, uhd, smart tv. base stand for salewe have many different model stand, other brands toosony xbr-55x900b base tv stand with screws 1210293847560 / 44781091132ld450. 43PF4500. 32UH5000. LC-46D85U. DX-L32-10A. BN61-11465X001 1210293847560 - 1210293847560 J5500/J6900Email me Your Tv model number.Price We Offer is the Final Sale. No Bargain, Interested Email.Others Good Luck.',
#  'looking to sell my samsung smart tv - excellent condition - has multiple apps associated so very easy to use with netflix, youtube and tmn on the go. as well can use your hard drive in usb ports for videos or songs to play.looking to sell for $350, this is about 66% less than i purchased it for.have all the original parts including 1110293847560 pair of 1210293847560 glasses .as well tv stand for $150 dollars - purchased at $300 -excellent condition as well with 1110293847560 glass shelves.shelf $15 dollars',
#  'Great picture quality with excellent contrast ratio. Includes remote control power swivel where you can tilt the tv to the left and right. Will also include a wall mount.Tv screen contains 1110293847560 small scratches that are about 1210293847560 each. Not very noticeable when tv is on. Hence the low selling price. Paid over $3200. No lowballers please.',
#  'Cracked screen selling for parts, make your offer.',
#  'Samsung tv for sale, just screen broken. plasma display. model PN42C430AID. you can use as a part',
#  ' 1210293847560 plasma screen TV with pilot and wall brackets included. All in mint condition.',
#  "For wall mounting any LCD, LED or. Plasma just remember one name. install-ON call 1210293847560 1210293847560 are company trained professionals. We will install your TV or sound system according to your needswe carry all hardware to make your installation easy and joyful, so you don't have to worry about anything",
#  "''''For wall mounting any LCD, LED or. Plasma just remember one name. install-ON call 1210293847560 1210293847560 are company trained professionals. We will install your TV or sound system according to your needswe carry all hardware to make your installation easy and joyful, so you don't have to worry about anythingOur Super Discounted all in one installation Package includes. wall mounting your up to 1210293847560 TV. All wires vertical concealed inside the drywall. FREE TV wall mount. wall plates provided. extension cord provided. all other necessary hard ware provided. call for quotecall 1210293847560 1210293847560 .toronto ajax pickring oshawa hilton hamilton hilton lcd wall mounting led wall mounting plasma wall mounting tv installation installation tv wall mounting flat screen tv installation tv installation tv wall mounting lcd tv wall mounting tv wall installation tv wall mount contractors wall mount contractors plasma tv wall mount installation lcd tv wall mount installation led tv wall mount installation installation of tv on wall free up living space hdtv wall mounting hdtv wall installation tv mounting contractor tv contractor wall mounting professional tv wall mounting professional contractor tv wall installation professional tv wall mount wall mount wallmount wall mounts lcd tv plasma tv led tv bracket cables stereo lcd tv television tv tvs highdefinition dvd stand electronics professional home theater mounting lcd tv wall mounting computer monitor projection audio video panel wall mount bracket wall bracket tv wall bracket tv wall mount bracket home theatre installation surround sound installation screen flat panel hdmi installation audio video *49.99 offer goes up to 1210293847560 hdmi cables brackets mount are not included. 1210293847560 1210293847560 1210293847560 hgdfh rhf ghfttgd 1210293847560 5476890-9=-098 1210293847560 1210293847560 53453",
#  " 1210293847560 Pioneer Plasma TV. It's in good working order. No damages. Pick up and cash only. If you want to test we can do that. If you have questions please ask",
#  'monoprice® 1210293847560 adjustable tilting tv wall mount bracket for 1210293847560 -26" plasma up to 1210293847560 lbs., blackmonoprice® adjustable tilting tv wall mount bracket in silver color is ideal for mounting led/lcd plasma tvs from size 1210293847560 - 1210293847560 and ideal for boardrooms or home theaters. Monoprice® Adjustable tilting tv wall mount bracket can handle a maximum load of 1210293847560 lbs and is angle adjustable. Bracket supports TVs sizing from 1210293847560 - 1210293847560 and includes a unique slim wall plate that keeps the screen close to the wall. Black. 1210293847560 x 1210293847560 wall-plate, 1210293847560 - 1210293847560 display support, 1210293847560 extension, 1210293847560 x 1210293847560 front plate. Weight capacity: Up to 1210293847560 lbs. Tilt angle: -15 deg. Construction: Steel. Supports VESA compliant displays with mounting patterns of 2210293847560 and 2210293847560 This high-quality tilting wall mount is intended for use with brick/concrete/block walls only. Features a low-profile design which puts the back of the TV only about 1. 1210293847560 from the wall. Includes Mounting hardware. Compatibility: LCD/LED/Plasma TV. Compliance: RoHSPlease contact Monique 416-968-3013',
#  ";;;if you have led lcd plazma tv get the best company to do the wall mounting. call 1210293847560 1210293847560 our tech are highly trained guys to install you Tv sound systemwe are company trained professionals. We will install your TV or sound system according to your needswe carry all hardware to make your installation easy and joyful,. so you don't have to worry about anythingorSelect our Super Discounted all in one installation Package includeswall mounting your up to 1210293847560 TV. All wires vertical concealed inside the drywall. FREE TV wall mount. wall plates provided. extension cord provided. all other necessary hard ware provided. call for quoteCall 1210293847560 6975;;;;. ;. ;;toronto ajax pickring oshawa hilton hamilton hilton lcd wall mounting led wall mounting plasma wall mounting tv installation installation tv wall mounting flat screen tv installation tv installation tv wall mounting lcd tv wall mounting tv wall installation tv wall mount contractors wall mount contractors plasma tv wall mount installation lcd tv wall mount installation led tv wall mount installation installation of tv on wall free up living space hdtv wall mounting hdtv wall installation tv mounting contractor tv contractor wall mounting professional tv wall mounting professional contractor tv wall installation professional tv wall mount wall mount wallmount wall mounts lcd tv plasma tv led tv bracket cables stereo lcd tv television tv tvs highdefinition dvd stand electronics. =989678 1210293847560 1210293847560 1210293847560 1210293847560 1210293847560 vr feghthy 1210293847560 1110293847560 3"]

# %% [markdown]
# ## NLP stage

# %%
# lol, hardcode tv as the lemma for tvs
my_subject_lemmas = [word.lemma_ if word.text != 'tvs' else 'tv' for word in nlp_full(my_subject)]
docs = [nlp_full(desc) for desc in descs]

# %% [markdown]
# ## Post-processing

# %%
def generate_preferred_spelling_dict(words):
    '''
    For some set of words, returns a dict mapping each unique lowercased word to
    its most popular spelling and total occurrences of all spellings.
    '''
    spellings = {}
    for word in words:
        word_lower = word.lower()
        if word_lower in spellings:
            spellings[word_lower].append(word)
        else:
            spellings[word_lower] = [word]
    preferred_spellings = {}
    for (word, spelling_cands) in spellings.items():
        n_occurrences = len(spelling_cands)
        preferred_spelling = max(set(spelling_cands), key=spelling_cands.count)
        preferred_spellings[word] = (preferred_spelling, n_occurrences)
    return preferred_spellings

def generate_multiplicity_dict(words):
    '''
    Counts the number of occurrences of each word, case-sensitive.
    '''
    multiplicities = {}
    for word in words:
        if word not in multiplicities:
            multiplicities[word] = words.count(word)
    return multiplicities

# %%
def cands_directly_describing_subject(cands, subj_descriptors):
    return [cand for cand in cands if cand.lower() in subj_descriptors]

# %%
# A dictionary of preferred spellings also contains word occurrence multiplicities
def highest_multiplicity_cand(cands, preferred_spellings):
    return max(cands, key=lambda cand: preferred_spellings[cand.lower()][1])

# %% [markdown]
# ### Identify brand candidates

# %%
def is_brand_model_candidate(word, tag, subject_lower):
    return tag in ['NNP'] and word.lower() != subject_lower

# %%
brand_blacklist = []
brand_whitelist = ['Panasonic', 'Samsung', 'Sharp', 'LG', 'Fujitsu', 'Philips', 'Sony', 'CCM', 'Norco', 'Raleigh', 'Shimano', 'Supercycle', 'Schwinn']
def contains_number(string):
     return any(char.isdigit() for char in string)
# Most brand names don't contain numbers, but many model names do
# Most brand names are not english words
def find_likely_brand_names(brands):
    whitelisted_brands = [brand for brand in brands if brand in brand_whitelist]
    if whitelisted_brands: return whitelisted_brands
    return [brand for brand in brands if not hobj.spell(brand) and not contains_number(brand)]

# %%
tagged_words_spacy = []
for doc in docs:
    tagged_words_spacy.append([(token.text, token.tag_) for token in doc])
    
my_subject_lower = my_subject.lower()
brand_model_cands = []
for sent in tagged_words_spacy:
    brand_model_cands.append([word for (word, tag) in sent if is_brand_model_candidate(word, tag, my_subject_lower)])
#brand_model_cands

# %% [markdown]
# ### Find features and their descriptions

# %%
listings_described_features = []
listings_orphaned_descriptors = []
stop_tags = ['PRP', 'DT'] #'IN'
for doc in docs:
    #spans = [span for span in list(doc.noun_chunks) ]
    #tokens = [(token, token.tag_) for span in spans for token in span]
    #print(tokens)
    described_features = []
    orphaned_descriptors = []
    for np in doc.noun_chunks:
        if np.root.tag_ not in stop_tags:
            interesting_descriptors = [
                word for word in np 
                    if not word.tag_ in stop_tags 
                    and not word.is_stop
                    and not word.text == np.root.text
            ]
            if np.root.lemma_ in my_subject_lemmas:
                print(interesting_descriptors)
                orphaned_descriptors.append(interesting_descriptors)
            else:
                described_features.append((interesting_descriptors, np.root.text))
    listings_described_features.append(described_features)
    listings_orphaned_descriptors.append(orphaned_descriptors)
#listing_orphaned_descriptors
#listing_noun_phrases
# Out:
# [Panasonic, 1210293847560, Plasma]
# [28, ”, Samsung, HD, Plasma]
# []
# [original]
# [1210293847560]
# [mint]
# [used, 1210293847560, Inch, Plasma]
# []
# [Pioneer, PDP, 1210293847560, HD]
# [plasma]
# [ , 1210293847560, plasma]
# []
# [Smart]
# []
# [makes-, led]
# [lcd]
# [plasma]
# [uhd, ,, smart]
# [camerawe're, specialized, inlcd]
# []
# [plasma]
# [Hitachi, 1210293847560, plasma]
# [1210293847560, plasma, screen]
# []
# []
# []
# [42, ”, Samsung, plasma]
# [ , 1210293847560]
# [Samsung, 1210293847560, DNIe, SRS, Tru, Surround, Xt, Plasma]
# [1210293847560, Plasma]
# [lcd, /, led, /, plasma]
# []
# [#, ceiling]
# [#, movie]
# [#, jadoo]
# [1210293847560]
# [north, bayou, mobile, cart]
# [1210293847560, samsung]
# []
# [1210293847560, samsung]
# []
# [vintage, electronics./, LED, /, LCD, /, Plasma]
# [42-inch, widescreen, enhanced, -, definition, plasma]
# [-, 1210293847560, widescreen, high, -, definition, plasma]
# []
# [Great]
# [beautiful]
# [beautiful, plazma]
# [broken, LCD, /, PLASMA]
# [broken]
# []
# [tv]
# []
# []
# [tv]
# [LED, /, LCD, /, Plasma, screen]
# []
# [Panasonic, Viera, -, 1210293847560, plasma]
# []
# [ , 1210293847560, plasma]
# [Panasonic, Viera, Plasma]
# [makes-, led]
# [lcd]
# [plasma]
# [uhd, ,, smart]
# [estimatewe're, specialized, inrepair]
# [lcd]
# [,, sharp, ,, samsung, ,, sony, ,, lg, ,, panasonic, ,, kindlcd]
# []
# [plasma]
# [,, 52lg50, ,, 55la6205led, hdtv, ,, plasma]
# [lcd]
# [modelslcd]
# []
# [plasma]
# [Plasma, HD]
# [ , 1210293847560, Panasonic, High, Definition, Plasma]
# [fireplace, height, adjustable, swivel]
# []
# []
# []
# [$, 59.99main]
# []
# [#, ceiling]
# [#, movie]
# [#, jadoo]
# []
# [1210293847560]
# []
# [panasonic, tcp50x5, plasma]
# [Panasonic, plasma]
# [Plasma]
# []
# [Just]
# [Legend, 42, ”]
# [Plasma]
# [Samsung, 1210293847560, 1210293847560, plasma]
# []
# [used, Sharp, Aquos, LCD]
# [Model, LC-42D62U., NEEDS, REPAIR, -]
# [ , 1210293847560, plasma]
# [new, 1210293847560, Panasonic, Viera, plasma]
# []
# []
# []
# []
# []
# []
# [1210293847560]
# []
# [LG, 1210293847560]
# [new]
# [ , 1210293847560, LG, Plasma]
# [Samsung, 1210293847560, Plasma]
# []
# [1210293847560, plasma, screen]
# [extra, flat, screen]
# []
# []
# [50, ”, plasma]
# [smart]
# [barely, used]
# []
# []
# []
# []
# [samsung, ,, lg, ,, sharp, ,, panasonic, ,, toshiba, ,, rca, ,, pioneer, prima, ,, etc, ..., led]
# [lcd]
# []
# [Plasma]
# [/, lcd, /, plasma]
# []
# [up, to, 1210293847560]
# [ , 1210293847560, Samsung, plasma]
# [broken, silver, Lg, 1210293847560, plasma]
# [”, plasma]
# [Audiophile]
# [too, much]
# []
# [1210293847560, Plasma]
# []
# [43, ”, Samsung]
# [new]
# []
# []
# []
# [great, basement]
# [https://www.cnet.com/products/samsung-pn42b430/specs/very, nice, black, housed]
# [Samgung]
# [non, working, lg]
# [tv, 's, 1210293847560, to, 1210293847560, led, ,, lcd, ,]
# []
# [Pioneer, Elite, 1210293847560, plasma]
# []
# [panasonic, brand, lcd]
# [panasonic, brand, lcd]
# []
# [black, 1210293847560, sharp]
# [LG, Plasma]
# []
# []
# []
# []
# [1, ), TV, -, 1210293847560, Panasonic]
# []
# [(]
# [Beovision4, -, 1210293847560]
# [Philips]
# [Plasma]
# []
# [Current]
# [vaunted, Pioneer, Elite]
# [Panasonic]
# []
# [most, other]
# [its]
# []
# [1210293847560]
# [second, Kuro]
# []
# [lcd]
# [non, working, lg]
# [makes-, led]
# [lcd]
# [plasma]
# [uhd, ,, smart]
# []
# [plasma]
# [led]
# [plasma]
# [,, smart]
# [base]
# []
# [professional, lcd, &, plasma, wall, mounting, &, installation, -any, size]
# []
# []
# [new, flat, panel]
# [lcd, or, plasma]
# [lcd, or, plasma]
# []
# []
# []
# []
# [lcd]
# [plasma]
# [led]
# []
# [lcd]
# [makes-, led]
# [lcd]
# [plasma]
# [uhd, ,, smart]
# [estimatewe're, specialized, inrepair]
# [lcd]
# [,, sharp, ,, samsung, ,, sony, ,, lg, ,, panasonic, ,, kindlcd]
# []
# [plasma]
# []
# []
# []
# [Samsung]
# [ , 1210293847560, plasma, screen]
# []
# []
# [up, to, 1210293847560]
# []
# [lcd, plasma]
# [ , 1210293847560, Pioneer, Plasma]
# [1210293847560, -26, "]
# []
# []
# [LCD, /, LED, /, Plasma]
# [lcd, plazma]
# [up, to, 1210293847560]
# []
# [lcd, plasma]

# %%
brand_names = []
flattened_cand_list = [cand for cands in brand_model_cands for cand in cands]
preferred_brand_spellings = generate_preferred_spelling_dict(flattened_cand_list)
for doc, brand_cands, listing_described_features in zip(
    docs, brand_model_cands, listings_described_features
):
    if not brand_cands:
        brand_names.append('')
        continue
        
    # See if one of the candidates is being used to directly describe the subject of
    #   the listing, rather than some other noun in the listing.
    feature_descriptors = [descriptors for (descriptors, feature) in listing_described_features if feature.lower() == my_subject_lower]
    flattened_feature_descriptors = [x.text.lower() for y in feature_descriptors for x in y]
    
    top_cands = find_likely_brand_names(brand_cands)
    if top_cands:
        top_top_cands = cands_directly_describing_subject(top_cands, flattened_feature_descriptors)
        if top_top_cands:
            top_cand = highest_multiplicity_cand(top_top_cands, preferred_brand_spellings)
        else:
            top_cand = highest_multiplicity_cand(top_cands, preferred_brand_spellings)
    else:
        top_cands = [cand for cand in brand_cands if cand.lower() in flattened_feature_descriptors]
        if top_cands:
            top_cand = highest_multiplicity_cand(top_cands, preferred_brand_spellings)
        else:
            top_cand = highest_multiplicity_cand(brand_cands, preferred_brand_spellings)
    
    brand_names.append(preferred_brand_spellings[top_cand.lower()][0])
#brand_names

# %%
popular_brands = [preferred_spelling for (key, preferred_spelling) in preferred_brand_spellings.items()]
popular_brands.sort(key=lambda brand: brand[1], reverse=True)
#popular_brands

# %%
features = [
    feature 
    for listing_described_features in listings_described_features
    for (descriptors, feature) in listing_described_features
]
feature_preferred_spellings = generate_preferred_spelling_dict(features)
popular_features = list(feature_preferred_spellings.items())
popular_features.sort(key=lambda desc: desc[1][1], reverse=True)

# %%
my_subject_lemmas
# Out:
# ['plasma', 'tv']

# %%
most_popular_features = [feature for (feature, _) in popular_features[:10]]
all_descriptors = set()
feature_descriptors = {feature:[] for feature in most_popular_features}
for listing_described_features in listings_described_features:
    for descriptors, feature in listing_described_features:
        feature = feature.lower()
        if feature in most_popular_features:
            feature_descriptions = []
            #already_handled = []
            for descriptor in descriptors:
                if descriptor in all_descriptors or descriptor.is_stop: continue
                if descriptor.head.text == feature:
                    full_description = []
                    # Not sure how valid the assumption is that the children will be
                    # in front of the main descriptor
                    for dependent_descriptor in descriptor.children:
                        if not dependent_descriptor.is_stop:
                            all_descriptors.add(dependent_descriptor)
                            full_description.append(dependent_descriptor.text)
                    all_descriptors.add(descriptor)
                    full_description.append(descriptor.text)
                    # This filters out a lot of stray punctuation
                    if not (len(full_description) == 1 and len(full_description[0]) == 1):
                        feature_descriptions.append(full_description)
            feature_descriptors[feature].append(feature_descriptions)
            
#for handled in already_handled:
#    print(handled)
            #print(subject)        
            #print(subject_descriptions)
#print(listings_orphaned_descriptors)
flattened_orphaned_descriptors = [
    descriptor.text
         for listing_orphaned_descriptors in listings_orphaned_descriptors
             for descriptors in listing_orphaned_descriptors
                 for descriptor in descriptors

]

preferred_descriptor_spellings = generate_preferred_spelling_dict(
    [descriptor.text for descriptor in all_descriptors] +
    flattened_orphaned_descriptors
)
#print([descriptor.text for descriptor in all_descriptors] + flattened_orphaned_descriptors)
#print(indirect_descriptor_phrases)
# for subject, listings in indirect_descriptor_phrases.items():
#     for i, listing in enumerate(listings):
#         for j, description in enumerate(listing):
#             print(description)
#             for k, descriptor in enumerate(description):
#                 #print(descriptor)
#                 preferred_spelling = preferred_descriptor_spellings[descriptor.lower()][0]
#                 if descriptor != preferred_spelling:
#                     indirect_descriptor_phrases[subject][i][j][k] = preferred_spelling
# print(indirect_descriptor_phrases)
top_descriptors = {feature:[] for feature in most_popular_features}
for feature, listings in feature_descriptors.items():
    flattened_indirect_descriptor_phrase_list = []
    for listing in listings:
        for description in listing:
            # This will unfortunately put spaces around hyphens, and that sort of thing
            #print(description)
            text_description = ' '.join([preferred_descriptor_spellings[descriptor.lower()][0] for descriptor in description])
            flattened_indirect_descriptor_phrase_list.append(text_description)
    preferred_descriptions = list(generate_multiplicity_dict(flattened_indirect_descriptor_phrase_list).items())

    top_descriptors[feature] = preferred_descriptions
    
for feature, descriptors in top_descriptors.items():
    descriptors.sort(key=lambda desc: desc[1], reverse=True)
    top_descriptors[feature] = descriptors[:5]

for feature, descriptors in top_descriptors.items():
    print(f'{feature}:')
    for descriptor, mult in descriptors:
        print(f'\t{descriptor} ({mult})')
        
def reassociate_orphaned_descriptor(orphaned_descriptor, features_descriptors):
    most_occurrences = 0
    for _, feature_descriptors in features_descriptors.items():
        #print(feature_descriptors)
        for i, (feature_descriptor, mult) in enumerate(feature_descriptors):
            #print(orphaned_descriptor, feature_descriptor)
            if orphaned_descriptor == feature_descriptor:
                if mult > most_occurrences: most_occurrences = mult
    for _, feature_descriptors in features_descriptors.items():
        #print(feature_descriptors)
        for i, (feature_descriptor, mult) in enumerate(feature_descriptors):
            if mult == most_occurrences and orphaned_descriptor == feature_descriptor:
                feature_descriptors[i] = (feature_descriptor, mult + 1)
                return True
    return False

true_orphans = []
for orphaned_descriptor in flattened_orphaned_descriptors:
    if len(orphaned_descriptor) == 1: continue
    orphaned_descriptor = preferred_descriptor_spellings[orphaned_descriptor.lower()][0]
    if not reassociate_orphaned_descriptor(orphaned_descriptor, top_descriptors):
        true_orphans.append(orphaned_descriptor)

preferred_orphan_descriptors = list(generate_multiplicity_dict(true_orphans).items())
preferred_orphan_descriptors.sort(key=lambda desc: desc[1], reverse=True)
        
print('Type:')
#print(preferred_orphan_descriptors)
for descriptor, mult in preferred_orphan_descriptors[:5]:
    print(f'\t{descriptor} ({mult})')
# Out:
# cables:
# 	audio (10)
# 	video (8)
# 	network (4)
# 	displayport (4)
# 	# & video audio (2)
# wall:
# 	tv (14)
# 	shelf- (6)
# 	professional tv (6)
# 	tilting (5)
# 	1210293847560 (4)
# installation:
# 	wall mount (8)
# 	75 - professional (6)
# 	85 - professional (6)
# 	105 - professional (6)
# 	25 - soundbar (6)
# mount:
# 	wall (19)
# 	basic (12)
# 	premium (12)
# 	tilt (6)
# 	full (6)
# condition:
# 	excellent (9)
# 	good (8)
# 	Great (7)
# 	working (6)
# 	acceptable (2)
# repair:
# 	tv (5)
# 	1210293847560 (5)
# 	store (5)
# 	dvr (3)
# 	computer (3)
# stand:
# 	tv (3)
# 	1210293847560 (2)
# 	Panasonic (2)
# 	matching (2)
# 	original (1)
# screen:
# 	flat (6)
# 	broken (5)
# 	1210293847560 (2)
# 	television (2)
# 	big (2)
# sale:
# 	moving (2)
# 	prefect condition (1)
# 	quick (1)
# 	tv (1)
# 	wall & mount (1)
# parts:
# 	jvc- (2)
# 	old (2)
# 	missing (2)
# 	computer (1)
# 	all (1)
# Type:
# 	plasma (61)
# 	lcd (27)
# 	Samsung (13)
# 	led (12)
# 	lg (9)

# %%
for brand, mult in popular_brands[:30]:
    print(f'{brand} ({mult})')
# Out:
# Panasonic (40)
# Plasma (32)
# HDMI (27)
# TV (25)
# lg (24)
# Samsung (16)
# LCD (10)
# Board (10)
# WALL (9)
# Viera (9)
# MOUNT (8)
# dlp (8)
# Professional (7)
# Sound (7)
# ESTIMATE (7)
# 3d (7)
# Repair (7)
# EXPERTLED (6)
# time!PRICES (6)
# CONSULTATION416 (6)
# HD (6)
# Free (6)
# Input (6)
# PLASMAQuality (5)
# haier (5)
# Specialized (5)
# Hard (5)
# Drive (5)
# kennedy (5)
# MONDAY (5)

# %%
#spacy.displacy.render(nlp_full('Hummel-Like Porcelain figurines , set of 6, mint condition'), style='dep', jupyter=True)

# %%
# for doc, original_desc in zip(docs, original_descs[:100]):
#     spacy.displacy.render(doc, style='dep', jupyter=True)

# %%
#descs

# %%
# import hunspell
# hobj = hunspell.HunSpell('/usr/share/hunspell/en_US.dic', '/usr/share/hunspell/en_US.aff')
# brand_model_cands

# %%
# testdoc = nlp_full('msrmnT1 tv with a msrmnT2 stand')
# testdoc2 = nlp_full('Here are the TV specs:. size: 1UmsrmnT1. HDMI ports: 2msrmnT2')
# spacy.displacy.render(testdoc, style='dep', jupyter = True)
# spacy.displacy.render(testdoc2, style='dep', jupyter = True)

# %%
# vectorizer = sk.feature_extraction.text.CountVectorizer()

# %%
# word_bag = vectorizer.fit_transform(important_words).toarray()
# bag_words = vectorizer.get_feature_names()
# # We don't care if a word appears multiple times in the same listing
# for (index, single_listing_word_multiplicity) in np.ndenumerate(word_bag):
#     if single_listing_word_multiplicity > 1: word_bag[index] = 1
# aggregate_multiplicities = word_bag.sum(axis=0)
# word_multiplicity = list(zip(bag_words, aggregate_multiplicities.tolist()))

# #word_multiplicity = np.column_stack((bag_words, aggregate_multiplicities))

# %%
# # https://stackoverflow.com/a/2828121
# #def sort_words_by_multiplicity(words):
# #    return words[words[:,1].argsort()]

# #sorted_words = sort_words_by_multiplicity(word_multiplicity)
# #sorted_words = sorted_words[::-1]
# #sorted_words[:30]

# word_multiplicity.sort(key=lambda word_multiplicity: word_multiplicity[1])
# word_multiplicity[::-1]

# %%
# def tag_words(text):
#       tokens = nl.word_tokenize(text)
#       return nl.pos_tag(tokens)

# %%
# def ner_words(text):
#       tokens = nl.word_tokenize(text)
#       return nl.chunk.ne_chunk(tokens)

# %%
# chunked_words = [nl.chunk.ne_chunk(desc) for desc in tagged_words]
# chunked_words

# %%
# #print(brand_model_cands)
# treated_words = set()
# spellings = {}
# for listing_cands in brand_model_cands:
#     for cand in listing_cands:
#         cand_lower = cand.lower()
#         if cand.lower() in spellings:
#             spellings[cand_lower].append(cand)
#         else:
#             spellings[cand_lower] = [cand]
# spellings

# %%
#preferred_spellings = {}
#single_spellings = set()
#for (word, spelling_cands) in spellings.items():
#    n_occurrences = len(spelling_cands)
#    preferred_spelling = max(set(spelling_cands), key=spelling_cands.count)
#    preferred_spellings[word] = (preferred_spelling, n_occurrences)
# preferred_spellings

# %%
#hummel_ads = {'1202550115': {'title': 'Hummel Style Japanese Girl Chicken', 'img': '<img alt="Hummel Style Japanese Girl Chicken" src="https://i.ebayimg.com/00/s/ODAwWDQ1MA==/z/ySEAAOSwTA9X5tuP/$_35.JPG"/>', 'url': 'http://www.kijiji.ca/v-art-collectibles/city-of-toronto/hummel-style-japanese-girl-chicken/1202550115', 'details': '', 'date': '< 23 hours ago', 'location': 'City of Toronto', 'price': '-1.00', 'description': 'Hummel Style Japanese 5 x 4 inches no chips cracks or fleas'}, '1358609245': {'title': 'Hummel "Trumpet Boy"', 'img': '<img alt=\'Hummel "Trumpet Boy"\' src="https://i.ebayimg.com/00/s/NjAwWDgwMA==/z/kJIAAOSw1xVbDIcB/$_35.JPG"/>', 'url': 'http://www.kijiji.ca/v-art-collectibles/city-of-toronto/hummel-trumpet-boy/1358609245', 'details': '', 'date': '20/09/2018', 'location': 'City of Toronto', 'price': '25.00', 'description': 'Early Goebel Hummel - Germany\n"Trumpet Boy" - #97\nStands 4 1/2" high'}, '1358607961': {'title': 'Hummel "Boy with Basket"', 'img': '<img alt=\'Hummel "Boy with Basket"\' src="https://i.ebayimg.com/00/s/NjAwWDgwMA==/z/yloAAOSw8SpbDIXj/$_35.JPG"/>', 'url': 'http://www.kijiji.ca/v-art-collectibles/city-of-toronto/hummel-boy-with-basket/1358607961', 'details': '', 'date': '20/09/2018', 'location': 'City of Toronto', 'price': '25.00', 'description': 'Early Goebel Hummel - Germany\n"Village Boy" #51 3/0\nStands 4" high'}, '1260421734': {'title': 'hummel like figurines', 'img': '<img alt="hummel like figurines" src="https://i.ebayimg.com/00/s/NjQwWDQ4MA==/z/PNgAAOSw7GRZB~Te/$_35.JPG"/>', 'url': 'http://www.kijiji.ca/v-art-collectibles/city-of-toronto/hummel-like-figurines/1260421734', 'details': '', 'date': '18/09/2018', 'location': 'City of Toronto', 'price': '35.00', 'description': 'Hummel-Like Porcelain figurines , set of 6, mint condition'}, '1259656455': {'title': 'vintage Hummel like porcelain', 'img': '<img alt="vintage Hummel like porcelain" src="https://i.ebayimg.com/00/s/NjQwWDQ4MA==/z/8HcAAOSwlndZBNhB/$_35.JPG"/>', 'url': 'http://www.kijiji.ca/v-art-collectibles/city-of-toronto/vintage-hummel-like-porcelain/1259656455', 'details': '', 'date': '14/09/2018', 'location': 'City of Toronto', 'price': '25.00', 'description': 'vintage Hummel like porcelain figurine, 5" high, mint condition'}, '1340613666': {'title': 'Hummels - "Little Gardner"; "School Girl"; or "For Mother"', 'img': '<img alt=\'Hummels - "Little Gardner"; "School Girl"; or "For Mother"\' src="https://i.ebayimg.com/00/s/NTMzWDgwMA==/z/D~IAAOSwwz5arsuK/$_35.JPG"/>', 'url': 'http://www.kijiji.ca/v-art-collectibles/city-of-toronto/hummels-little-gardner-school-girl-or-for-mother/1340613666', 'details': '', 'date': '09/09/2018', 'location': 'City of Toronto', 'price': '50.00', 'description': 'Beautiful figurines. No chips or scratches. Complete with name tags attached. Excellent condition. Looking for $50.00 each, will accept reasonable offer'}, '1355433085': {'title': 'Hummel " Apple Tree Boy " Figurine', 'img': '<img alt=\'Hummel " Apple Tree Boy " Figurine\' src="https://i.ebayimg.com/00/s/NjAwWDgwMA==/z